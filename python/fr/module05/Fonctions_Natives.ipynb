# %% [markdown]
# # Les Fonctions natives Python
#
# L'interpréteur Python propose plusieurs fonctions et types natifs disponibles à l'installation de Python. Ces fonctios et types facilitent la programmation en évitant de recréer la roue.
# Ils sont listés ici par ordre alphabétique ici : https://docs.python.org/fr/3/library/functions.html
#
#
# ##### Instructeur: Joan Mouba, Dr.-Ing. en Informatique
# L'utilisation de ce fichier est sous la license GPL.
# Vous pouvez utiliser, modifier et redistribuer librement.
#
# Merci de soutenir notre travail en nous laissant un avis et en vous abonnant à nos canaux  canaux. Nous serons aussi reconnaissant si vous mentionnez l'auteur et/ou la référence source du Notebook pour toute réutilisation:
# [https://bit.ly/3skCdlO](https://colab.research.google.com/drive/1ajrZfkap-L-ZnXBkfKyQmSdi5tgBHZ-Z?usp=sharing)
#
# LinkedIn: [![LinkedIn](https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&style=social&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/joanmouba/) - https://www.linkedin.com/in/joanmouba/
#
# Web: [https://epignosiscenter.com](https://epignosiscenter.com)
#
# Courriel: joan.mouba@epignosiscenter.com
#
# Canal Youtube: [![YouTube](https://img.shields.io/youtube/channel/subscribers/UCjqWeYtZ82DBan-vhFzkTog)](https://www.youtube.com/channel/UCjqWeYtZ82DBan-vhFzkTog)
#
# Répertoire GitHub:[![GitHub](https://img.shields.io/badge/GitHub-100000?style=for-the-badge&style=social&logo=github&logoColor=white)](https://github.com/JoanMouba)
#
# Merci de me laisser un avis sur Google: [Je laisse mon avis sur la formation](https://g.page/r/CRFbaxcVvqo9EAI/review)
#
# Dernière mise à jour: 25.12.2023 par [Joan Mouba](https://g.page/r/CRFbaxcVvqo9EAI/review)

# %% [markdown]
# ## Liste des fonctions natives
# Disponible pour Python 3.12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A
# * abs()
# * aiter()
# * all()
# * anext()
# * any()
# * ascii()

# %% [markdown]
# ### `abs(x)`
# Renvoie la valeur absolue d'un nombre. L'argument peut être un entier, un nombre à virgule flottante ou un objet implémentant __abs__(). Si l'argument est un nombre complexe, sa magnitude est retournée.

# %%
distance = 234
salaire_mensuel = 6454.89
courant = 3 + 5j

# %%
# Calculer leur valeur absolue ici
print(abs(distance))
print(abs(salaire_mensuel))
print(abs(courant))
# Out:
# 234
# 6454.89
# 5.830951894845301

# %% [markdown]
# ### `all(iterable)`
# Renvoie `True` si tous les éléments de iterable sont vrais (ou s'il est vide). Équivaut à :
#
#
# ```
# def all(iterable):
#     for element in iterable:
#         if not element:
#             return False
#     return True
# ```

# %%
depenses = [23, 566, 78]
comparaisons = [6544, " ", -34, 677, True, 5>14]

# %%
# Vérifier si tous les éléments de ces itérables sont vraies
print(all(depenses))
print(all(comparaisons))
# Out:
# True
# False

# %% [markdown]
# ### `any(iterable)`
# Renvoie True si au moins un élément de iterable est vrai. False est renvoyé dans le cas où iterable est vide. Équivaut à :
#
#
# ```
# def any(iterable):
#     for element in iterable:
#         if element:
#             return True
#     return False
# ```

# %%
revenus = [7885, 566, 78]
comparaisons = [6544, " ", -34, 677, True, 5>14]
inegalites = [False, False, False, False]

# %%
# Vérifier si au moins un des éléments de ces itérables est vrai
print(any(revenus))
print(any(comparaisons))
print(any(inegalites))
# Out:
# True
# True
# False

# %%
N = int(input())
integers_str = input().split()

all_positive = all([int(number)>=0 for number in integers_str])
any_palindromic = any([number == number[::-1] for number in integers_str] )

if 0 < N < 100:
    if all_positive and any_palindromic:
        print(True)
    else:
        print(False)
# Out:
# 5
# 12 9 61 5 14
# True

# %% [markdown]
# #### Exercice
#
# Ecrivez un code Python qui:
# 1.   Vérifie si tout les entiers de la liste sont positifs
# 2.   Vérifie s'il contient au moins un nombre pair
# 3.   Si ces deux conditions sont remplies, renvoyez `True` sinon `False`
# 4.   Tester ce code avec les listes suivantes:
# *   `[12, -44, 236, 420]`
# *   `[66, 24, 35, 17, 2]`

# %%
### votre code solution ici

# %% [markdown]
# ### `ascii(objet)`
# Renvoie, tout comme `repr()`, une chaîne contenant une représentation d'un objet destinée à l'affichage, mais en transformant les caractères non ASCII renvoyés par `repr()` par l'utilisation de séquences d'échappement `\x`, `\u` ou `\U`. Cela génère une chaîne similaire à ce que renvoie `repr()` dans Python 2.

# %% [markdown]
# #### Table ascii
# Lien: https://upload.wikimedia.org/wikipedia/commons/thumb/1/1b/ASCII-Table-wide.svg/1280px-ASCII-Table-wide.svg.png
#
# **bold text**
# ![image.png](data:image/png;base64,...)

# %%
mot_sans_accent = "Bonjour la famille"
mot_avec_accent = "les écolier sont prêts."
# Out:
# 'Bonjour la famille'
# "'les \\xe9colier sont pr\\xeats.'"

# %%
# Affichez ces mots après avoir appliquer la fonction ascii()
print(ascii(mot_sans_accent))
print(ascii(mot_avec_accent))
# Out:
# 'Bonjour la famille'
# 'les \xe9colier sont pr\xeats.'

# %% [markdown]
# ## B
#
# * bin()
# * bool()
# * breakpoint()
# * bytearray()
# * bytes()

# %% [markdown]
# ### `bin(x)`
# Convertit un nombre entier en une chaîne binaire préfixée par "0b". Le résultat est une expression Python valide. Si x n'est pas un objet Python int, il doit définir une méthode __index__() qui renvoie un entier.

# %%
age = 34
decouvert_bancaire = -1100
quantite_bouteille = 1.5

# %%
# Affichez la représentation binaire de ces nombres
print(bin(age))
print(bin(decouvert_bancaire))
print(bin(quantite_bouteille))
# Out:
# 0b100010
# -0b10001001100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-34770504b2ec> in <cell line: 4>()
#       2 print(bin(age))
#       3 print(bin(decouvert_bancaire))
# ----> 4 print(bin(quantite_bouteille))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ### `bool(x=False)`
# Renvoie une valeur booléenne, c'est-à-dire True ou False. x est converti à l'aide de la procédure standard de vérification de la vérité.

# %% [markdown]
# #### Vérification standard de la vérité
# Tout objet peut être comparé à une valeur booléenne, généralement dans une condition if ou while ou en tant qu'opérande des opérations booléennes ci-dessous.
#
# Par défaut, un objet est considéré comme vrai à moins que sa classe ne définisse une méthode __bool__() qui renvoie False ou une méthode __len__() qui renvoie zéro, lorsqu'elle est appelée avec l'objet. 1 Voici la plupart des objets intégrés considérés comme faux :
#
# constantes définies comme fausses : None et False
#
# zéro de tout type numérique : 0, 0.0, 0j, Decimal(0), Fraction(0, 1)
#
# les chaînes vides et les collections : '', (), [], {}, set(), range(0)
#
# Les opérations et fonctions natives dont le résultat est booléen renvoient toujours 0 ou False pour false et 1 ou True pour true, sauf indication contraire (exception importante : les opérations booléennes or et renvoient toujours l'un de leurs opérandes).

# %%
val1 = "bonjour"
val2 = []
val3 = False
val4 = None
val5 = 34.66

# %%
# Calculer les valeurs booléennes de variables

# %% [markdown]
# ### `breakpoint()`
# Cette fonction vous place dans le débogueur lorsqu'elle est appelée. Depuis Python 3.7+.
# Avant on utilisait: `import pdb; pdb.set_trace()`
#
# Fonctions du débogeur:
#
# *   h: help
# *   w: where
# *   n: next
# *   s: step (steps into function)
# *   c: continue
# *   p: print
# *   l: list
# *   q: quit

# %%
def calcul_somme_entiers(x, y):
    resultat = x + y
    print(x + y)
    return x + y

entier1 = 345.34
entier2 = 455
breakpoint()
resultat = calcul_somme_entiers(entier1, entier2)

breakpoint()
print(resultat)
print("Teminé")
# Out:
# --Return--
# None
# > <ipython-input-4-7ec65db9484a>(8)<cell line: 8>()
#       6 entier1 = 345.34
#       7 entier2 = 455
# ----> 8 breakpoint()
#       9 resultat = calcul_somme_entiers(entier1, entier2)
#      10
#
# ipdb> q

# %% [markdown]
# ### `bytearray()`
# class `bytearray(source=b'', encoding, errors)`
# Renvoie un nouveau tableau d'octets. La classe bytearray est une séquence mutable de nombres entiers dans l'intervalle 0 ≤ x < 256. Il possède la plupart des méthodes des séquences variables, décrites dans Types de séquences mutables, ainsi que la plupart des méthodes de la classe `bytes`, voir Opérations sur les `bytes` et `bytearray`.
#
# Le paramètre optionnel source peut être utilisé pour initialiser le tableau de plusieurs façons :
#
# * si c'est une chaîne, vous devez aussi donner le paramètre encoding pour l'encodage (et éventuellement errors). La fonction bytearray() convertit ensuite la chaîne en octets via la méthode str.encode() ;
#
# * si c'est un entier, le tableau a cette taille et est initialisé d'octets null ;
#
# * si c'est un objet conforme à l'interface tampon, un tampon en lecture seule de l'objet est utilisé pour initialiser le tableau ;
#
# * si c'est un itérable, il doit itérer sur des nombres entier dans l'intervalle 0 <= x < 256, qui sont utilisés pour initialiser le contenu du tableau.
#
# * Sans argument, un tableau vide est créé.

# %%
compliment = "Python is beautiful and easy to learn"
iban = [123, 45, 79]

# %%
print(bytearray(compliment, encoding='utf-16'))
print(bytearray(iban))
# Out:
# bytearray(b'\xff\xfeP\x00y\x00t\x00h\x00o\x00n\x00 \x00i\x00s\x00 \x00b\x00e\x00a\x00u\x00t\x00i\x00f\x00u\x00l\x00 \x00a\x00n\x00d\x00 \x00e\x00a\x00s\x00y\x00 \x00t\x00o\x00 \x00l\x00e\x00a\x00r\x00n\x00')
# bytearray(b'{-O')

# %% [markdown]
# ### `bytes()`
# class `bytes(source=b'', encoding, errors)`
# Renvoie un nouvel objet bytes, qui est une séquence immuable de nombres entiers dans l'intervalle 0 <= x < 256. Un bytes est une version immuable de bytearray — avec les mêmes méthodes d'accès, et le même comportement lors de l'indexation ou du découpage.
#
# En conséquence, les arguments du constructeur sont les mêmes que pour bytearray().
#
# *   Les objets bytes (octets) peuvent aussi être créés à partir de littéraux, voir Littéraux de chaînes de caractères et de suites d'octets.
#
# *   Les objets octets contiennent des données lisibles par une machine et nous pouvons stocker un objet octet directement dans le stockage secondaire.

# %%
compliment = "Python is a high-level language"
vitesse = 12

# %%
print(bytes(compliment, encoding='utf-16'))
print(bytes(vitesse))
# Out:
# b'\xff\xfeP\x00y\x00t\x00h\x00o\x00n\x00 \x00i\x00s\x00 \x00a\x00 \x00h\x00i\x00g\x00h\x00-\x00l\x00e\x00v\x00e\x00l\x00 \x00l\x00a\x00n\x00g\x00u\x00a\x00g\x00e\x00'
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %% [markdown]
# ## C
#
#
# * callable()
# * chr()
# * classmethod()
# * compile()
# * complex()

# %% [markdown]
# ## D
#
# * delattr()
# * dict()
# * dir()
# * divmod()

# %% [markdown]
# ## E
#
# * enumerate()
# * eval()
# * exec()

# %% [markdown]
# ### `enumerate(x)`
# Renvoie un objet énumérant. iterable doit être une séquence, un itérateur, ou tout autre objet prenant en charge l'itération. La méthode __next__() de l'itérateur donné par enumerate() renvoie un n-uplet contenant un compte (démarrant à start, 0 par défaut) et les valeurs obtenues de l'itération sur iterable.
#
# https://pythonbasics.org/enumerate/

# %% [markdown]
# Enumérer une liste

# %%
fruits = ['pomme', 'orange', 'mangue', 'prune']

# %%
for index in range(len(fruits)):
    print(index, fruits[index])
# Out:
# 0 pomme
# 1 orange
# 2 mangue
# 3 prune

# %%
for position, value in enumerate(fruits):
    print(position, value)
# Out:
# 0 pomme
# 1 orange
# 2 mangue
# 3 prune

# %%
for un_fruit in enumerate(fruits):
    print(un_fruit)
# Out:
# (0, 'pomme')
# (1, 'orange')
# (2, 'mangue')
# (3, 'prune')

# %% [markdown]
# Enumérer avec un différent départ

# %%
for index, fruit in enumerate(fruits, start=2):
    print(index, fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4fbffac88a55> in <cell line: 1>()
# ----> 1 for index, fruit in enumerate(fruits, start=2):
#       2     print(index, fruit)
#
# NameError: name 'fruits' is not defined

# %%
for position, value in enumerate(fruits, 10):
    print(position, value)
# Out:
# 10 pomme
# 11 orange
# 12 mangue
# 13 prune

# %% [markdown]
# Énumérer une liste de tuples

# %%
# fruits et leurs nombres
panier_fruits = [("Orange", 5), ("Raisins",15), ("Pommes", 6)]

for index, type_fruit in enumerate(panier_fruits):
    print(index, type_fruit)
# Out:
# 0 ('Orange', 5)
# 1 ('Raisins', 15)
# 2 ('Pommes', 6)

# %% [markdown]
# Énumérer une chaîne de caractères

# %%
salutations = "Je vous salut Monsieur le président"

for index, caractere in enumerate(salutations):
    print(index, caractere)
# Out:
# 0 J
# 1 e
# 2
# 3 v
# 4 o
# 5 u
# 6 s
# 7
# 8 s
# 9 a
# 10 l
# 11 u
# 12 t
# 13
# 14 M
# 15 o
# 16 n
# 17 s
# 18 i
# 19 e
# 20 u
# 21 r
# 22
# 23 l
# 24 e
# 25
# 26 p
# 27 r
# 28 é
# 29 s
# 30 e
# 31 i
# 32 d
# 33 e
# 34 n
# 35 t

# %% [markdown]
# Bonus: énumérer dictionnaire

# %%
chiffres_en_anglais = {'un':'one', 'deux':'two', 'trois':'three', 'quatre':'four'}

for cle, valeur in chiffres_en_anglais.items():
    print(cle, 'en anglais est', valeur)
# Out:
# un en anglais est one
# deux en anglais est two
# trois en anglais est three
# quatre en anglais est four

# %% [markdown]
# ### Exercice
# Déterminez la position de la voiture "Skoda" dans la liste
#  * `garage = ['BMW', 'Peugeot', 'Nissan', 'Skoda', 'Alpha roméo'] `
#  * Utilisez la fonction native `enumerate() `

# %% [markdown]
# ### Exercice
# quel est el navigateur qui est ?a la position `3` dans la liste
#  * `navigateurs = ['Opera', 'Chrome', 'Edge', 'Netscape', 'Alpha roméo'] `
#  * Utilisez la fonction native `enumerate() `

# %%
# Out:
# index:  0   fruit: pomme
# index:  1   fruit: orange
# index:  2   fruit: mangue
# index:  3   fruit: prune

# %% [markdown]
# ### `eval(expression, globals=None, locals=None)`
#
# Cette fonction permet l'exécution dynamique de code Python. expression doit être soit une chaîne soit un objet code. Si c'est une chaîne, elle est d'abord analysée en une suite d'instructions Python qui sont ensuite exécutés (sauf erreur de syntaxe). Si c'est un objet code, il est simplement exécuté. Dans tous les cas, le code fourni doit être valide selon les mêmes critères que s'il était un script dans un fichier. Gardez en tête que les mots clés `nonlocal`, `yield` et `return` ne peuvent pas être utilisés en dehors d'une fonction, même dans du code passé à eval(). La fonction renvoie None.
#
# Les arguments sont : une chaîne, et optionnellement des locales et des globales. S'il est fourni, `globals` doit être un dictionnaire. S'il est fourni, `locals` peut être n'importe quel objet mapping.
#
# L'argument expression est analysé et évalué comme une expression Python (techniquement, une condition list) en utilisant les dictionnaires `globals` et `locals` comme espaces de nommage global et local.
#
# Cette fonction peut aussi être utilisée pour exécuter n'importe quel objet code (tels que ceux créés par `compile()`). Dans ce cas, donnez un objet code plutôt qu'une chaîne. Si l'objet code a été compilé avec l'argument mode à `'exec'`, `eval()` renvoie None.

# %%
eval('45 - 6 +2')
# Out:
# 41

# %%
salaire_mensuel = 6300
eval('salaire_mensuel + 300')
# Out:
# 6600

# %%
# vous ne pouvez pas faire des assignations de valeur avec eval
salaire_mensuel = 6300
eval('salaire_annuel = salaire_mensuel + 300')
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-bf6e6e4feb06>", line 3, in <cell line: 3>
#     eval('salaire_annuel = salaire_mensuel + 300')
#
#   File "<string>", line 1
#     salaire_annuel = salaire_mensuel + 300
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Exercice
# Ecrivez un code Python qui:
# 1.   prend une instruction Python en entrée
# à l'aide de la fonction `input()`
# 2.   Affiche cette expression avec `print()`
# 3.   Evalue cette expression avec `eval()`
# 4.   Testez votre code avec les expressions suivantes:
# *   print('Hello Monde')
# *   34 - 56
# *   x = 23
# *   int('102') + 45

# %%
# Votre code solution ici

# %% [markdown]
# ### `exec(object, globals=None, locals=None, /, *, closure=None)`
# Cette fonction permet l'exécution dynamique de code Python. `object` doit être soit une chaîne soit un objet code. Si c'est une chaîne, elle est d'abord analysée en une suite d'instructions Python qui sont ensuite exécutés (sauf erreur de syntaxe). Si c'est un objet code, il est simplement exécuté. Dans tous les cas, le code fourni doit être valide selon les mêmes critères que s'il était un script dans un fichier. Gardez en tête que les mots clés nonlocal, `yield` et `return` ne peuvent pas être utilisés en dehors d'une fonction, même dans du code passé à `exec()`. La fonction renvoie None.

# %%
code = """
# Depenses mensuelles
voiture = 100
loyer = 500
nourriture = 350
depenses_totales = voiture + loyer + nourriture
print('Dépenses:', depenses_totales, 'EUR')
"""

exec(code)
# Out:
# Dépenses: 950 EUR

# %% [markdown]
# #### Exercice
# Créez un code qui définit une chaîne de caractère contenant du code Python valide.
# Ce code valide calcule et affiche la somme des revenus d'un individu  qui a les gains mensuels suivants:
#
# 1.   salaire de 6000 EUR
# 2.   revenus de la bourse de 200 EUR
# 3.   revenus immobiliers de 700 EUR

# %%
# votre code solution ici

# %% [markdown]
# ## F
#
# * filter()
# * float()
# * format()
# * frozenset()

# %% [markdown]
# ### `filter(function, iterable)`
# Construit un itérateur depuis les éléments d'iterable pour lesquels function renvoie `True`. iterable peut aussi bien être une séquence, un conteneur qui prend en charge l'itération, ou un itérateur. Si function est None, la fonction identité est prise, c'est-à-dire que tous les éléments faux d'iterable sont supprimés.
#
# Notez que `filter(function, iterable)` est l'équivalent du générateur `(item for item in iterable if function(item))` si function n'est pas None, et de `(item for item in iterable if item)` si function est None.
#
# Voir `itertools.filterfalse()` pour la fonction complémentaire qui donne les éléments d'iterable pour lesquels function renvoie `False`.

# %%
# Filtrer les nombres pairs


def verifie_parite(nombre):
    if nombre % 2 == 0:
        return True
    return False


# Application
elements = [244, 56, 78, 22, 21, 7855, 980]

elements_filtres = list(filter(verifie_parite, elements))

print(elements_filtres)
# Out:
# [244, 56, 78, 22, 980]

# %%
# Filtrer les villes qui commencent par 'M'

def check_start_with_M(name):
    if name.startswith('M'):
        return True
    return False

villes = ['Lisbonne', 'Madrid', 'Macau', 'Stockolm', 'Magdebourg', 'Berlin']

villes_en_M = list( filter(check_start_with_M, villes))
villes_en_M
# Out:
# ['Madrid', 'Macau', 'Magdebourg']

# %%
# Filter avec une fonction anonyme (Lambda)
# identifier les nombres pairs

nombres = [244, 56, 78, 22, 21, 7855, 980]
nombres_pairs = list( filter(lambda x: (x%2 == 0), nombres) )

print(nombres_pairs)
# Out:
# [244, 56, 78, 22, 980]

# %%
# Filter avec  None comme fonction
# identifier les éléments qui renvoient `False` si on leur applique `bool()`

corbeille = [False, [], "Bonjour", 34, True, 34.7, "", -21, 0, 15, (4, 6)]
corbeille_nettoyee = list( filter(None, corbeille) )

print(corbeille_nettoyee)
# Out:
# ['Bonjour', 34, True, 34.7, -21, 15, (4, 6)]

# %% [markdown]
# #### Exercice
# Utilisez `filter()` pour:
#
# * identifier et afficher les personnes dont le nom de famille sont `Blanc` de la liste suivante: `['Luc Blanc', 'Claude Petit', 'Xen Blanc', 'Joe Dax', 'Cathy Marin', 'Marius Persan', 'Samira Blanc', 'Claire Maisac']`
#
# * identifier et afficher les personnes dont le salaire est supérieur à 6000 EUR de la liste des tuples (salaire, nom) suivante: `[(4564,'Luc Blanc'), (6500, 'Claude Petit'), (7800, 'Xen Blanc'), (4700, 'Joe Dax'), (2300, 'Cathy Marin'), (2800, 'Marius Persan'), (8800, 'Samira Blanc'), (15200, 'Claire Maisac')]`

# %%
# votre code solution ici

# %% [markdown]
# ### `float(x=0.0)`
# Renvoie un nombre a virgule flottante depuis un nombre ou une chaîne `x`.
#
# Si l'argument est une chaîne, elle doit contenir un nombre décimal, éventuellement précédé d'un signe, et pouvant être entouré d'espaces. Le signe optionnel peut être `'+'` ou `'-`'. Un signe `'+'` n'a pas d'effet sur la valeur produite. L'argument peut aussi être une chaîne représentant un `NaN` (Not-a-Number ou pas un nombre en français), l'infini positif, ou l'infini négatif. Plus précisément, l'argument doit se conformer à floatvalue tel que défini la grammaire suivante, après que les espaces en début et fin de chaîne aient été retirées :
#
# * sign        ::=  "+" | "-"
# * infinity    ::=  "Infinity" | "inf"
# * nan         ::=  "nan"
# * digitpart   ::=  `!digit` (["_"] `!digit`)*
# * number      ::=  [digitpart] "." digitpart | digitpart ["."]
# * exponent    ::=  ("e" | "E") ["+" | "-"] digitpart
# * floatnumber ::=  number [exponent]
# * floatvalue  ::=  [sign] (floatnumber | infinity | nan)
#
# Pour un objet Python général `x`, `float(x)` est délégué à `x.__float__()`. Si `__float__()` n'est pas défini alors il est délégué à `__index__()`.

# %%
# Code
print(float('+1.23'))
print(float('   -12345\n'))
print(float('1e-003'))
print(float('+1E6'))
print(float('-Infinity'))
print(float('1234_564_56.90'))
# Out:
# 1.23
# -12345.0
# 0.001
# 1000000.0
# -inf
# 123456456.9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-139ef3d82749> in <cell line: 8>()
#       6 print(float('-Infinity'))
#       7 print(float('1234_564_56.90'))
# ----> 8 print(float('tt'))
#
# ValueError: could not convert string to float: 'tt'

# %% [markdown]
# #### Exercice
# Utilisez `float()` pour convertir les éléments de la liste suivante en nombre à virgule flottante:
#
# * chaque élément de la liste [' 677', ' INFINITY ', -9898, 3.14E4]
# * affichez chaque élément de la liste précédente avec deux chiffres après la virgule

# %%
# votre code solution ici

# %% [markdown]
# ### `format(value, format_spec='')`
# Convertit une valeur en sa représentation « formatée », contrôlée par format_spec. L'interprétation de format_spec dépend du type de la valeur. Cependant, il existe une syntaxe standard utilisée par la plupart des types natifs : Mini-langage de spécification de format.
#
# Par défaut, format_spec est une chaîne vide. Dans ce cas, appeler cette fonction a généralement le même effet qu'appeler str(value).

# %%
# Exemples
presentation1 = "Mon nom est {fvorname} {fname}, J'ai {age} ans".format(fvorname="John", fname = "Doe", age = 44)
presentation2 = "Mon nom est {0} {1}, J'ai {2} ans".format("Clara", "Doe", 22)
presentation3 = "Mon nom est {1} {0}, J'ai {2} ans".format("Max", "John", 16)
presentation4 = "Mon nom est {} {}, J'ai {} ans".format("Brio", "Doe", 12)

identite = ("Bonnie", "Doe", 42)
presentation5 = "Mon nom est {} {}, J'ai {} ans".format(*identite)

# %%
print(presentation1)
print(presentation2)
print(presentation3)
print(presentation4)
print(presentation5)
# Out:
# Mon nom est John Doe, J'ai 44 ans
# Mon nom est Clara Doe, J'ai 22 ans
# Mon nom est John Max, J'ai 16 ans
# Mon nom est Brio Doe, J'ai 12 ans
# Mon nom est Bonnie Doe, J'ai 42 ans

# %%
# Autres exemples

# affiche avec 2 chiffres après la virgule
description = "Cet ordinateur coûte {prix:.2f} Euros"
print( description.format(prix = 123455.4567))

# affiche avec un séparateur de milliers '_'
description = "Cet ordinateur coûte {prix:_.2f} Euros"
print( description.format(prix = 123455.4567))


# aligne à droite avec espaces à gauche pour un emplacement de 15 caractères
description = "Cet ordinateur coûte {prix:>15_.2f} Euros"
print( description.format(prix = 123455.4567))

# aligne au centre avec * padding à gauche et à droite, et ',' en séparateur de milliers
description = "Cet ordinateur coûte {prix:*^15,.4f} Euros" # center
print( description.format(prix = 123455.4567))

# aligne à gauche avec zéro padding à droite
description = "Cet ordinateur coûte {prix:0<15,.2f} Euros"
print( description.format(prix = 123455.4567))
# Out:
# Cet ordinateur coûte 123455.46 Euros
# Cet ordinateur coûte 123_455.46 Euros
# Cet ordinateur coûte      123_455.46 Euros
# Cet ordinateur coûte *123,455.4567** Euros
# Cet ordinateur coûte 123,455.4600000 Euros

# %% [markdown]
# #### Exercice
# Utilisez `format()` pour afficher le texte ci-dessous à partir du tuple `('Jennifer', 'Smith', 'Designer', 34, 145_566.8934)  `
#
# * `Mon nom est Jennifer Smith, J'ai 34 ans. Je suis Designer. Mon salaire annuel est de 145_566.89`
# * `Mon nom est Clasmin Mobbs, J'ai 64 ans. Je suis Manager IT. Mon salaire annuel est de 165_443.10`

# %% [markdown]
# ### `class frozenset(iterable=set())`
# Renvoie un nouvel objet de type `frozenset`, dont les objets sont éventuellement tirés d'`iterable`. `frozenset` est une classe native. Permet de figer l'iterable et le rendre immutable.
#
# Pour d'autres conteneurs, voyez les classes natives `set`, `list`, `tuple`, et `dict`, ainsi que le module `collections`.

# %%
# Exemple
corbeille = ['pomme', 'cerise', 'raisins', 'mandarine']
corbeille[1] = 'banane'
print(corbeille)
# Out:
# ['pomme', 'banane', 'raisins', 'mandarine']

# %%
corbeille_protegee = frozenset(corbeille)
corbeille_protegee[1] = 'papaye'

print(corbeille_protegee)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-6a9374d7197d> in <cell line: 2>()
#       1 corbeille_protegee = frozenset(corbeille)
# ----> 2 corbeille_protegee[1] = 'papaye'
#       3
#       4 print(corbeille_protegee)
#
# TypeError: 'frozenset' object does not support item assignment

# %% [markdown]
# #### Exercice
# Il vous a été confié un code pour l'accès des employés dans l'entreprise. On vous demande de protéger ces informations contre toute modification en utilisant un type frozenset.
# démontrez que cela marche.
#
# * code en chaîne de caractère: `"ujjtxuirll"`

# %%
# votre code solution ici

# %% [markdown]
# ## G
#
# * getattr()
# * globals()

# %% [markdown]
# ## H
#
# * hasattr()
# * hash()
# * help()
# * hex()

# %% [markdown]
# ## I
#
# * id()
# * input()
# * int()
# * isinstance()
# * issubclass()
# * iter()

# %% [markdown]
# ## L
#
# * len()
# * list()
# * locals()

# %% [markdown]
# ## M
#
# * map()
# * max()
# * memoryview()
# * min()

# %% [markdown]
# ## N
#
# * next()

# %% [markdown]
# ## O
#
# * object()
# * oct()
# * open()
# * ord()

# %% [markdown]
# ## P
#
# * pow()
# * print()
# * property()

# %% [markdown]
# ## R
#
# * range()
# * repr()
# * reversed()
# * round()

# %% [markdown]
# ## S
#
# * set()
# * setattr()
# * slice()
# * sorted()
# * staticmethod()
# * str()
# * sum()
# * super()

# %% [markdown]
# ## T
#
# * tuple()
# * type()

# %% [markdown]
# ## V
#
# * vars()

# %% [markdown]
# ## Z
#
# * zip()

# %% [markdown]
# ## Autres
#
# * __import__()
